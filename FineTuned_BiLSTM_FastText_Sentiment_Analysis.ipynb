# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import fasttext
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
# Check for GPU availability
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Download NLTK resources
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Rizvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Custom Dataset

# %%
class BanglaDataset(Dataset):
    def __init__(self, df, max_seq_len=184, fasttext_model=None):
        self.df = df
        self.nsamples = len(self.df)
        self.fasttext_model = fasttext_model  # FastText model
        self.max_seq_len = max_seq_len

    def __getitem__(self, index):
        review = self.df.iloc[index]['clean_sentence']
        sentiment = self.df.iloc[index]['Sentiment']

        word_list = word_tokenize(review)
        x = []
        for w in word_list:
            w = w.lower()
            # Get the vector from the FastText model
            x.append(self.fasttext_model.get_word_vector(w))

        # Convert to 2D array if not empty
        if len(x) > 0:
            x = np.array(x)
        else:
            x = np.zeros((self.max_seq_len, 300))  # Ensure x is padded even if empty

        # Truncate if greater than max len
        x = x[:self.max_seq_len]
        # Padding if less than max len
        padding_len = self.max_seq_len - x.shape[0]
        padding = np.zeros((padding_len, 300))  # Padding should match the embedding dimension
        x = np.concatenate((x, padding), axis=0)

        y = sentiment

        x = torch.FloatTensor(x)
        y = torch.LongTensor([y])  # Use LongTensor for class labels

        return x, y

    def __len__(self):
        return self.nsamples

# %% [markdown]
# # Load Fine Tuned Directory

# %%
# Load FastText model
fasttext_model = fasttext.load_model(r'E:\Bangla-Sentiment-Analysis\Word Embeddings\fine_tuned_FastText_2.bin')

# %% [markdown]
# # Model

# %%
class LSTM_Model(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, num_classes=3, bidirectional=True, dropout_rate=0.2):
        super(LSTM_Model, self).__init__()
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, bidirectional=bidirectional)
        self.bidirectional = bidirectional
        self.dropout = nn.Dropout(dropout_rate)
        if bidirectional:
            self.fc = nn.Linear(hidden_dim * 2, num_classes)
        else:
            self.fc = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        output, (hn, cn) = self.lstm(x)
        if self.bidirectional:
            hn = torch.cat((hn[-2], hn[-1]), dim=1)  # final forward and backward states
        else:
            hn = hn.squeeze(0)
        hn = self.dropout(hn)  # dropout
        pred = self.fc(hn)
        return pred

# Initialize loss function
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# # Load Dataset

# %%
# Split dataset into train+val and test sets (80% train+val, 20% test)
train_val_df = pd.read_excel(r'E:\Bangla-Sentiment-Analysis\Bangla_Dataset\train_val_data_df.xlsx') 
test_df = pd.read_excel(r'E:\Bangla-Sentiment-Analysis\Bangla_Dataset\test_data_df.xlsx')

# Convert Sentiments to numeric labels
sentiment_mapping = {'Positive': 2, 'Neutral': 1, 'Negative': 0}
train_val_df['Sentiment'] = train_val_df['Sentiment'].map(sentiment_mapping)

sentiment_mapping = {'Positive': 2, 'Neutral': 1, 'Negative': 0}
test_df['Sentiment'] = test_df['Sentiment'].map(sentiment_mapping)

# %%
# K-Fold Cross Validation
kf = KFold(n_splits=8, shuffle=True, random_state=42)
fold = 0

# To store metrics and losses for each fold
all_fold_metrics = []
all_fold_train_losses = []
all_fold_val_losses = []
best_fold_index = -1
best_val_loss_overall = float('inf')

# %% [markdown]
# # Train Model

# %%
for train_index, val_index in kf.split(train_val_df):
    fold += 1
    model = LSTM_Model(embedding_dim=300, hidden_dim=64, num_classes=3, bidirectional=True, dropout_rate=0.5)
    model.to(DEVICE)
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-5)

    print(f"\nStarting Fold {fold}")
    train_data = train_val_df.iloc[train_index]
    val_data = train_val_df.iloc[val_index]

    # Initialize datasets
    train_dataset = BanglaDataset(train_data, fasttext_model=fasttext_model)
    validation_dataset = BanglaDataset(val_data, fasttext_model=fasttext_model)

    # Create dataloaders
    train_dataloader = DataLoader(dataset=train_dataset, batch_size=8, shuffle=True, num_workers=0)
    validation_dataloader = DataLoader(dataset=validation_dataset, batch_size=8, shuffle=True, num_workers=0)

    # Train the model
    nepoch = 10
    fold_train_loss = []
    fold_val_loss = []

    best_val_loss = float('inf')
    best_metrics = {'accuracy': 0, 'f_score': 0, 'precision': 0, 'recall': 0, 'best_epoch': 0}

    for i in range(nepoch):
        print(f"\nEpoch {i + 1}:")

        # --- Training ---
        model.train()
        tr_loss, n_tr_steps = 0., 0

        for step, batch in enumerate(train_dataloader):
            batch = tuple(t.to(DEVICE) for t in batch)
            (x, y) = batch

            optimizer.zero_grad()
            out = model(x)
            loss = loss_fn(out, y.view(-1))
            tr_loss += loss.item()
            n_tr_steps += 1

            loss.backward()
            optimizer.step()

        mean_train_loss = tr_loss / n_tr_steps
        fold_train_loss.append(mean_train_loss)

        # --- Validation ---
        model.eval()
        val_loss, n_val_steps = 0., 0
        predictions, labels = [], []
        with torch.no_grad():
            for step, batch in enumerate(validation_dataloader):
                batch = tuple(t.to(DEVICE) for t in batch)
                (x, y) = batch
                out = model(x)
                loss = loss_fn(out, y.view(-1))
                val_loss += loss.item()
                n_val_steps += 1

                # Collect predictions
                preds = torch.argmax(out, dim=1)
                predictions += preds.cpu().numpy().tolist()
                labels += y.cpu().numpy().tolist()

        mean_val_loss = val_loss / n_val_steps
        fold_val_loss.append(mean_val_loss)

        # --- Calculate Metrics ---
        accuracy = accuracy_score(labels, predictions)
        f_score = f1_score(labels, predictions, average="weighted")
        precision = precision_score(labels, predictions, average="weighted")
        recall = recall_score(labels, predictions, average="weighted")

        # Print metrics for the current epoch
        print(f'Train Loss: {mean_train_loss:.4f}, Validation Loss: {mean_val_loss:.4f}')
        print(f'Accuracy: {accuracy:.4f}, F Score: {f_score:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}')

        # Store best metrics for this fold
        if mean_val_loss < best_val_loss:
            best_val_loss = mean_val_loss
            best_metrics = {
                'best_epoch': i + 1,  # Store 1-based index for epoch
                'accuracy': accuracy,
                'f_score': f_score,
                'precision': precision,
                'recall': recall,
                'train_loss': mean_train_loss,  # Store best train loss
                'val_loss': mean_val_loss       # Store best validation loss
            }
            # Save the model weights of the best epoch in this fold
            torch.save(model.state_dict(), f"best_finetuned_fasttext_bilstm_model_fold_{fold}.pt")

    # Store losses for this fold
    all_fold_train_losses.append(fold_train_loss)
    all_fold_val_losses.append(fold_val_loss)

    # Store metrics for this fold
    all_fold_metrics.append(best_metrics)

    # Track the best fold based on validation loss
    if best_val_loss < best_val_loss_overall:
        best_val_loss_overall = best_val_loss
        best_fold_index = fold - 1  # Store the fold index (0-based)

    # After the fold training is complete
    print(f"\nBest Metrics for Fold {fold}:")
    print(f"Best Epoch: {best_metrics['best_epoch']}")
    print(f"Train Loss: {best_metrics['train_loss']:.4f}, Validation Loss: {best_metrics['val_loss']:.4f}")
    print(f"Accuracy: {best_metrics['accuracy']:.4f}, F Score: {best_metrics['f_score']:.4f}")
    print(f"Precision: {best_metrics['precision']:.4f}, Recall: {best_metrics['recall']:.4f}")
# Out:
# Starting Fold 1
#
# Epoch 1:
# Train Loss: 0.7269, Validation Loss: 0.6700
# Accuracy: 0.7290, F Score: 0.7222, Precision: 0.7192, Recall: 0.7290
#
# Epoch 2:
# Train Loss: 0.6681, Validation Loss: 0.6215
# Accuracy: 0.7471, F Score: 0.7303, Precision: 0.7349, Recall: 0.7471
#
# Epoch 3:
# Train Loss: 0.6444, Validation Loss: 0.6087
# Accuracy: 0.7592, F Score: 0.7533, Precision: 0.7516, Recall: 0.7592
#
# Epoch 4:
# Train Loss: 0.6245, Validation Loss: 0.5960
# Accuracy: 0.7649, F Score: 0.7571, Precision: 0.7580, Recall: 0.7649
#
# Epoch 5:
# Train Loss: 0.6135, Validation Loss: 0.5876
# Accuracy: 0.7730, F Score: 0.7661, Precision: 0.7658, Recall: 0.7730
#
# Epoch 6:
# Train Loss: 0.6058, Validation Loss: 0.6137
# Accuracy: 0.7612, F Score: 0.7455, Precision: 0.7568, Recall: 0.7612
#
# Epoch 7:
# Train Loss: 0.5996, Validation Loss: 0.5840
# Accuracy: 0.7741, F Score: 0.7659, Precision: 0.7670, Recall: 0.7741
#
# Epoch 8:
# Train Loss: 0.6124, Validation Loss: 0.5955
# Accuracy: 0.7684, F Score: 0.7642, Precision: 0.7657, Recall: 0.7684
#
# Epoch 9:
# Train Loss: 0.6045, Validation Loss: 0.5857
# Accuracy: 0.7658, F Score: 0.7564, Precision: 0.7603, Recall: 0.7658
#
# Epoch 10:
# Train Loss: 0.5874, Validation Loss: 0.5803
# Accuracy: 0.7718, F Score: 0.7670, Precision: 0.7656, Recall: 0.7718
#
# Best Metrics for Fold 1:
# Best Epoch: 10
# Train Loss: 0.5874, Validation Loss: 0.5803
# Accuracy: 0.7718, F Score: 0.7670
# Precision: 0.7656, Recall: 0.7718
#
# Starting Fold 2
#
# Epoch 1:
# Train Loss: 0.7262, Validation Loss: 0.6512
# Accuracy: 0.7356, F Score: 0.7185, Precision: 0.7207, Recall: 0.7356
#
# Epoch 2:
# Train Loss: 0.6670, Validation Loss: 0.6123
# Accuracy: 0.7509, F Score: 0.7452, Precision: 0.7425, Recall: 0.7509
#
# Epoch 3:
# Train Loss: 0.6431, Validation Loss: 0.5988
# Accuracy: 0.7618, F Score: 0.7570, Precision: 0.7548, Recall: 0.7618
#
# Epoch 4:
# Train Loss: 0.6224, Validation Loss: 0.5895
# Accuracy: 0.7721, F Score: 0.7668, Precision: 0.7654, Recall: 0.7721
#
# Epoch 5:
# Train Loss: 0.6148, Validation Loss: 0.5912
# Accuracy: 0.7670, F Score: 0.7660, Precision: 0.7668, Recall: 0.7670
#
# Epoch 6:
# Train Loss: 0.6061, Validation Loss: 0.5897
# Accuracy: 0.7647, F Score: 0.7607, Precision: 0.7587, Recall: 0.7647
#
# Epoch 7:
# Train Loss: 0.5974, Validation Loss: 0.5828
# Accuracy: 0.7727, F Score: 0.7677, Precision: 0.7671, Recall: 0.7727
#
# Epoch 8:
# Train Loss: 0.5940, Validation Loss: 0.5841
# Accuracy: 0.7684, F Score: 0.7642, Precision: 0.7658, Recall: 0.7684
#
# Epoch 9:
# Train Loss: 0.5864, Validation Loss: 0.5739
# Accuracy: 0.7733, F Score: 0.7673, Precision: 0.7667, Recall: 0.7733
#
# Epoch 10:
# Train Loss: 0.5801, Validation Loss: 0.5842
# Accuracy: 0.7695, F Score: 0.7679, Precision: 0.7697, Recall: 0.7695
#
# Best Metrics for Fold 2:
# Best Epoch: 9
# Train Loss: 0.5864, Validation Loss: 0.5739
# Accuracy: 0.7733, F Score: 0.7673
# Precision: 0.7667, Recall: 0.7733
#
# Starting Fold 3
#
# Epoch 1:
# Train Loss: 0.7237, Validation Loss: 0.6875
# Accuracy: 0.7213, F Score: 0.7056, Precision: 0.7065, Recall: 0.7213
#
# Epoch 2:
# Train Loss: 0.6692, Validation Loss: 0.6466
# Accuracy: 0.7445, F Score: 0.7379, Precision: 0.7365, Recall: 0.7445
#
# Epoch 3:
# Train Loss: 0.6403, Validation Loss: 0.6202
# Accuracy: 0.7534, F Score: 0.7464, Precision: 0.7459, Recall: 0.7534
#
# Epoch 4:
# Train Loss: 0.6221, Validation Loss: 0.6207
# Accuracy: 0.7552, F Score: 0.7454, Precision: 0.7474, Recall: 0.7552
#
# Epoch 5:
# Train Loss: 0.6111, Validation Loss: 0.6011
# Accuracy: 0.7618, F Score: 0.7572, Precision: 0.7559, Recall: 0.7618
#
# Epoch 6:
# Train Loss: 0.6062, Validation Loss: 0.5965
# Accuracy: 0.7658, F Score: 0.7566, Precision: 0.7573, Recall: 0.7658
#
# Epoch 7:
# Train Loss: 0.5987, Validation Loss: 0.6037
# Accuracy: 0.7638, F Score: 0.7609, Precision: 0.7619, Recall: 0.7638
#
# Epoch 8:
# Train Loss: 0.5936, Validation Loss: 0.5895
# Accuracy: 0.7690, F Score: 0.7646, Precision: 0.7651, Recall: 0.7690
#
# Epoch 9:
# Train Loss: 0.5865, Validation Loss: 0.5922
# Accuracy: 0.7655, F Score: 0.7587, Precision: 0.7613, Recall: 0.7655
#
# Epoch 10:
# Train Loss: 0.5803, Validation Loss: 0.5935
# Accuracy: 0.7635, F Score: 0.7535, Precision: 0.7567, Recall: 0.7635
#
# Best Metrics for Fold 3:
# Best Epoch: 8
# Train Loss: 0.5936, Validation Loss: 0.5895
# Accuracy: 0.7690, F Score: 0.7646
# Precision: 0.7651, Recall: 0.7690
#
# Starting Fold 4
#
# Epoch 1:
# Train Loss: 0.7289, Validation Loss: 0.6657
# Accuracy: 0.7296, F Score: 0.7185, Precision: 0.7192, Recall: 0.7296
#
# Epoch 2:
# Train Loss: 0.6680, Validation Loss: 0.6369
# Accuracy: 0.7420, F Score: 0.7376, Precision: 0.7403, Recall: 0.7420
#
# Epoch 3:
# Train Loss: 0.6409, Validation Loss: 0.6246
# Accuracy: 0.7503, F Score: 0.7450, Precision: 0.7473, Recall: 0.7503
#
# Epoch 4:
# Train Loss: 0.6358, Validation Loss: 0.6065
# Accuracy: 0.7624, F Score: 0.7511, Precision: 0.7556, Recall: 0.7624
#
# Epoch 5:
# Train Loss: 0.6210, Validation Loss: 0.5976
# Accuracy: 0.7621, F Score: 0.7594, Precision: 0.7582, Recall: 0.7621
#
# Epoch 6:
# Train Loss: 0.6066, Validation Loss: 0.5903
# Accuracy: 0.7638, F Score: 0.7565, Precision: 0.7575, Recall: 0.7638
#
# Epoch 7:
# Train Loss: 0.6005, Validation Loss: 0.5902
# Accuracy: 0.7661, F Score: 0.7619, Precision: 0.7610, Recall: 0.7661
#
# Epoch 8:
# Train Loss: 0.5956, Validation Loss: 0.5864
# Accuracy: 0.7621, F Score: 0.7565, Precision: 0.7558, Recall: 0.7621
#
# Epoch 9:
# Train Loss: 0.5888, Validation Loss: 0.5856
# Accuracy: 0.7664, F Score: 0.7593, Precision: 0.7622, Recall: 0.7664
#
# Epoch 10:
# Train Loss: 0.5833, Validation Loss: 0.5975
# Accuracy: 0.7649, F Score: 0.7551, Precision: 0.7602, Recall: 0.7649
#
# Best Metrics for Fold 4:
# Best Epoch: 9
# Train Loss: 0.5888, Validation Loss: 0.5856
# Accuracy: 0.7664, F Score: 0.7593
# Precision: 0.7622, Recall: 0.7664
#
# Starting Fold 5
#
# Epoch 1:
# Train Loss: 0.7256, Validation Loss: 0.6739
# Accuracy: 0.7330, F Score: 0.7179, Precision: 0.7202, Recall: 0.7330
#
# Epoch 2:
# Train Loss: 0.6695, Validation Loss: 0.6429
# Accuracy: 0.7466, F Score: 0.7377, Precision: 0.7365, Recall: 0.7466
#
# Epoch 3:
# Train Loss: 0.6440, Validation Loss: 0.6247
# Accuracy: 0.7589, F Score: 0.7502, Precision: 0.7509, Recall: 0.7589
#
# Epoch 4:
# Train Loss: 0.6228, Validation Loss: 0.6138
# Accuracy: 0.7638, F Score: 0.7544, Precision: 0.7562, Recall: 0.7638
#
# Epoch 5:
# Train Loss: 0.6153, Validation Loss: 0.6046
# Accuracy: 0.7655, F Score: 0.7596, Precision: 0.7585, Recall: 0.7655
#
# Epoch 6:
# Train Loss: 0.6101, Validation Loss: 0.6119
# Accuracy: 0.7589, F Score: 0.7574, Precision: 0.7562, Recall: 0.7589
#
# Epoch 7:
# Train Loss: 0.6052, Validation Loss: 0.6069
# Accuracy: 0.7670, F Score: 0.7537, Precision: 0.7608, Recall: 0.7670
#
# Epoch 8:
# Train Loss: 0.5953, Validation Loss: 0.5958
# Accuracy: 0.7649, F Score: 0.7606, Precision: 0.7588, Recall: 0.7649
#
# Epoch 9:
# Train Loss: 0.5881, Validation Loss: 0.6068
# Accuracy: 0.7635, F Score: 0.7567, Precision: 0.7573, Recall: 0.7635
#
# Epoch 10:
# Train Loss: 0.5813, Validation Loss: 0.5908
# Accuracy: 0.7661, F Score: 0.7603, Precision: 0.7594, Recall: 0.7661
#
# Best Metrics for Fold 5:
# Best Epoch: 10
# Train Loss: 0.5813, Validation Loss: 0.5908
# Accuracy: 0.7661, F Score: 0.7603
# Precision: 0.7594, Recall: 0.7661
#
# Starting Fold 6
#
# Epoch 1:
# Train Loss: 0.7315, Validation Loss: 0.6734
# Accuracy: 0.7319, F Score: 0.7188, Precision: 0.7197, Recall: 0.7319
#
# Epoch 2:
# Train Loss: 0.6788, Validation Loss: 0.6397
# Accuracy: 0.7460, F Score: 0.7412, Precision: 0.7396, Recall: 0.7460
#
# Epoch 3:
# Train Loss: 0.6528, Validation Loss: 0.6264
# Accuracy: 0.7638, F Score: 0.7599, Precision: 0.7600, Recall: 0.7638
#
# Epoch 4:
# Train Loss: 0.6313, Validation Loss: 0.6094
# Accuracy: 0.7672, F Score: 0.7565, Precision: 0.7610, Recall: 0.7672
#
# Epoch 5:
# Train Loss: 0.6182, Validation Loss: 0.6089
# Accuracy: 0.7647, F Score: 0.7619, Precision: 0.7603, Recall: 0.7647
#
# Epoch 6:
# Train Loss: 0.6099, Validation Loss: 0.5918
# Accuracy: 0.7713, F Score: 0.7623, Precision: 0.7641, Recall: 0.7713
#
# Epoch 7:
# Train Loss: 0.5985, Validation Loss: 0.6002
# Accuracy: 0.7661, F Score: 0.7586, Precision: 0.7609, Recall: 0.7661
#
# Epoch 8:
# Train Loss: 0.5965, Validation Loss: 0.5914
# Accuracy: 0.7681, F Score: 0.7611, Precision: 0.7634, Recall: 0.7681
#
# Epoch 9:
# Train Loss: 0.5891, Validation Loss: 0.5877
# Accuracy: 0.7724, F Score: 0.7678, Precision: 0.7681, Recall: 0.7724
#
# Epoch 10:
# Train Loss: 0.5835, Validation Loss: 0.5853
# Accuracy: 0.7695, F Score: 0.7600, Precision: 0.7625, Recall: 0.7695
#
# Best Metrics for Fold 6:
# Best Epoch: 10
# Train Loss: 0.5835, Validation Loss: 0.5853
# Accuracy: 0.7695, F Score: 0.7600
# Precision: 0.7625, Recall: 0.7695
#
# Starting Fold 7
#
# Epoch 1:
# Train Loss: 0.7349, Validation Loss: 0.6734
# Accuracy: 0.7269, F Score: 0.7254, Precision: 0.7250, Recall: 0.7269
#
# Epoch 2:
# Train Loss: 0.6752, Validation Loss: 0.6399
# Accuracy: 0.7433, F Score: 0.7308, Precision: 0.7327, Recall: 0.7433
#
# Epoch 3:
# Train Loss: 0.6465, Validation Loss: 0.6214
# Accuracy: 0.7531, F Score: 0.7506, Precision: 0.7495, Recall: 0.7531
#
# Epoch 4:
# Train Loss: 0.6296, Validation Loss: 0.6033
# Accuracy: 0.7623, F Score: 0.7527, Precision: 0.7547, Recall: 0.7623
#
# Epoch 5:
# Train Loss: 0.6175, Validation Loss: 0.5977
# Accuracy: 0.7663, F Score: 0.7572, Precision: 0.7608, Recall: 0.7663
#
# Epoch 6:
# Train Loss: 0.6097, Validation Loss: 0.6000
# Accuracy: 0.7591, F Score: 0.7496, Precision: 0.7577, Recall: 0.7591
#
# Epoch 7:
# Train Loss: 0.6026, Validation Loss: 0.5813
# Accuracy: 0.7712, F Score: 0.7636, Precision: 0.7648, Recall: 0.7712
#
# Epoch 8:
# Train Loss: 0.5968, Validation Loss: 0.5811
# Accuracy: 0.7726, F Score: 0.7667, Precision: 0.7674, Recall: 0.7726
#
# Epoch 9:
# Train Loss: 0.5910, Validation Loss: 0.5895
# Accuracy: 0.7706, F Score: 0.7653, Precision: 0.7652, Recall: 0.7706
#
# Epoch 10:
# Train Loss: 0.5796, Validation Loss: 0.5801
# Accuracy: 0.7718, F Score: 0.7666, Precision: 0.7667, Recall: 0.7718
#
# Best Metrics for Fold 7:
# Best Epoch: 10
# Train Loss: 0.5796, Validation Loss: 0.5801
# Accuracy: 0.7718, F Score: 0.7666
# Precision: 0.7667, Recall: 0.7718
#
# Starting Fold 8
#
# Epoch 1:
# Train Loss: 0.7214, Validation Loss: 0.7068
# Accuracy: 0.7195, F Score: 0.7056, Precision: 0.7055, Recall: 0.7195
#
# Epoch 2:
# Train Loss: 0.6641, Validation Loss: 0.6715
# Accuracy: 0.7310, F Score: 0.7256, Precision: 0.7230, Recall: 0.7310
#
# Epoch 3:
# Train Loss: 0.6329, Validation Loss: 0.6550
# Accuracy: 0.7445, F Score: 0.7362, Precision: 0.7358, Recall: 0.7445
#
# Epoch 4:
# Train Loss: 0.6165, Validation Loss: 0.6506
# Accuracy: 0.7499, F Score: 0.7406, Precision: 0.7424, Recall: 0.7499
#
# Epoch 5:
# Train Loss: 0.6051, Validation Loss: 0.6397
# Accuracy: 0.7502, F Score: 0.7416, Precision: 0.7411, Recall: 0.7502
#
# Epoch 6:
# Train Loss: 0.5982, Validation Loss: 0.6437
# Accuracy: 0.7453, F Score: 0.7435, Precision: 0.7459, Recall: 0.7453
#
# Epoch 7:
# Train Loss: 0.5902, Validation Loss: 0.6370
# Accuracy: 0.7502, F Score: 0.7418, Precision: 0.7423, Recall: 0.7502
#
# Epoch 8:
# Train Loss: 0.5834, Validation Loss: 0.6385
# Accuracy: 0.7545, F Score: 0.7461, Precision: 0.7473, Recall: 0.7545
#
# Epoch 9:
# Train Loss: 0.5777, Validation Loss: 0.6388
# Accuracy: 0.7548, F Score: 0.7424, Precision: 0.7490, Recall: 0.7548
#
# Epoch 10:
# Train Loss: 0.5733, Validation Loss: 0.6325
# Accuracy: 0.7557, F Score: 0.7462, Precision: 0.7505, Recall: 0.7557
#
# Best Metrics for Fold 8:
# Best Epoch: 10
# Train Loss: 0.5733, Validation Loss: 0.6325
# Accuracy: 0.7557, F Score: 0.7462
# Precision: 0.7505, Recall: 0.7557

# %%
# Print the best fold details
print("\n--------------------------------------------------Best Fold Summary---------------------------------------------------------------------------")

best_fold_metrics = all_fold_metrics[best_fold_index]  # Retrieve the metrics of the best fold

# Print the metrics for the best fold
print(f"Best Fold: {best_fold_index + 1}")
print(f"Best Epoch: {best_fold_metrics['best_epoch']}")
print(f"Train Loss: {best_fold_metrics['train_loss']:.4f}")
print(f"Validation Loss: {best_fold_metrics['val_loss']:.4f}")
print(f"Accuracy: {best_fold_metrics['accuracy']:.4f}")
print(f"F Score: {best_fold_metrics['f_score']:.4f}")
print(f"Precision: {best_fold_metrics['precision']:.4f}")
print(f"Recall: {best_fold_metrics['recall']:.4f}")

# Retrieve the best fold's train and validation loss
best_fold_train_loss = all_fold_train_losses[best_fold_index]
best_fold_val_loss = all_fold_val_losses[best_fold_index]

# Plot the best fold's training and validation loss
plt.figure(figsize=(10, 5))
plt.title(f"Training and Validation Loss for Best Fold (Fold {best_fold_index + 1})")
plt.plot(best_fold_train_loss, label="Training Loss")
plt.plot(best_fold_val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# --------------------------------------------------Best Fold Summary---------------------------------------------------------------------------
# Best Fold: 2
# Best Epoch: 9
# Train Loss: 0.5864
# Validation Loss: 0.5739
# Accuracy: 0.7733
# F Score: 0.7673
# Precision: 0.7667
# Recall: 0.7733

# %% [markdown]
# # Test Model

# %%
print("\n--------------------------------------------------Test Set---------------------------------------------------------------------------")

# After all folds, use the best model (based on validation loss) to evaluate the test dataset
print("\nEvaluating on Test Dataset")

# Prepare the test dataset and dataloader
test_dataset = BanglaDataset(test_df, fasttext_model=fasttext_model)
test_dataloader = DataLoader(dataset=test_dataset, batch_size=8, shuffle=False, num_workers=0)


# Load the best model's saved weights for the best fold (use the fold with best validation performance)
best_fold_model = LSTM_Model(embedding_dim=300, hidden_dim=64, num_classes=3, bidirectional=True, dropout_rate=0.5)
best_fold_model.load_state_dict(torch.load(f"best_finetuned_fasttext_bilstm_model_fold_{best_fold_index + 1}.pt"))
best_fold_model.to(DEVICE)

# Move to GPU and evaluate on the test dataset
best_fold_model.eval()
test_predictions, test_labels = [], []
with torch.no_grad():
    for step, batch in enumerate(test_dataloader):
        batch = tuple(t.to(DEVICE) for t in batch)
        (x, y) = batch
        out = best_fold_model(x)
        preds = torch.argmax(out, dim=1)
        test_predictions += preds.cpu().numpy().tolist()
        test_labels += y.cpu().numpy().tolist()
# Out:
# --------------------------------------------------Test Set---------------------------------------------------------------------------
#
# Evaluating on Test Dataset
# C:\Users\Rizvi\AppData\Local\Temp\ipykernel_12600\4168296695.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_fold_model.load_state_dict(torch.load(f"best_finetuned_fasttext_bilstm_model_fold_{best_fold_index + 1}.pt"))

# %%
# Compute test metrics
test_accuracy = accuracy_score(test_labels, test_predictions)
test_f_score = f1_score(test_labels, test_predictions, average="weighted")
test_precision = precision_score(test_labels, test_predictions, average="weighted")
test_recall = recall_score(test_labels, test_predictions, average="weighted")

# Display the final test metrics
print(f"Test Accuracy: {test_accuracy:.4f}, F Score: {test_f_score:.4f}")
print(f"Test Precision: {test_precision:.4f}, Test Recall: {test_recall:.4f}")

# Generate classification report
print("\nClassification Report:")
print(classification_report(test_labels, test_predictions, target_names=['Negative', 'Neutral', 'Positive']))

# Generate confusion matrix
cm = confusion_matrix(test_labels, test_predictions)
print("\nConfusion Matrix:")
print(cm)

# Visualizing the confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("Confusion Matrix")
plt.show()
# Out:
# Test Accuracy: 0.7736, F Score: 0.7659
# Test Precision: 0.7657, Test Recall: 0.7736
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.80      0.80      0.80      2291
#      Neutral       0.65      0.48      0.55      1445
#     Positive       0.79      0.88      0.84      3224
#
#     accuracy                           0.77      6960
#    macro avg       0.75      0.72      0.73      6960
# weighted avg       0.77      0.77      0.77      6960
#
#
# Confusion Matrix:
# [[1843  184  264]
#  [ 275  693  477]
#  [ 182  194 2848]]
